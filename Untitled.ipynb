# %%
# load data set
import pandas as pd
file_path = "heart-disease.csv"
df = pd.read_csv(file_path)
df.info(), df.head()

# %%
missing_values = df.isnull().sum()
sum_stat = df.describe()
missing_values, sum_stat
